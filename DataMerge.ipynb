# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ozelgun = pd.read_csv('Dim_OzelGunTanimlari.csv')
imha = pd.read_csv('imha_2014-2016.txt', sep = '\t')
satis = pd.read_csv('satis_2014-2016.txt', sep = '\t')
stok = pd.read_csv('stok_2014-2016.txt', sep = '\t')
mal = pd.read_csv('mal_2016.csv', sep = ';')

# %%
satis['TarihIndex'] = pd.to_datetime(satis['Tarih'], format='%d.%m.%Y')
imha['TarihIndex'] = pd.to_datetime(imha['Tarih'], format='%d.%m.%Y')
stok['TarihIndex'] = pd.to_datetime(stok['Tarih'], format= '%d.%m.%Y')

# %%
mal['KategoriTamami'] = mal["KategoriAnaGrupNo"].map(
    str)+ "" + mal["KategoriGrupNo"].map(str)+ "" + mal["KategoriSinifNo"].map(
    str)+ "" + mal["KategoriAltSinifNo"].map(str)

# %%
satisTarihIndex = satis.drop(['Tarih', 'Magaza', 'KategoriNo', 'KategoriGrupNo',
                              'KategoriAnaGrupNo', 'KategoriSinifNo', 'KategoriAltSinifNo'], axis = 1)
imhaTarihIndex = imha.drop(['Tarih', 'Magaza'], axis = 1)
stokTarihIndex = stok.drop(['Tarih', 'Magaza'], axis = 1)

# %%
mal['KategoriTamami'] = mal["KategoriAnaGrupNo"].map(
    str)+ "" +mal["KategoriGrupNo"].map(str)+ "" + mal["KategoriSinifNo"].map(
    str)+ "" + mal["KategoriAltSinifNo"].map(str)

# %%
mal['KategoriSinifTamami'] = mal["KategoriAnaGrupNo"].map(str)+ "" + mal["KategoriGrupNo"].map(
    str)+ "" + mal["KategoriSinifNo"].map(str)

# %%
malOzellik = mal.merge(mal[['MalNo','KategoriTamami']].groupby(
    'KategoriTamami').count().rename(columns = {'MalNo' : 'UrunSayisi'}),on = 'KategoriTamami', how = 'inner')

# %%
malOzellik['UrunSayisi'] = malOzellik['UrunSayisi'] -  1

# %%
malOzellik2 = malOzellik.merge(mal[['MalNo','KategoriSinifTamami']].groupby(
    'KategoriSinifTamami').count().rename(columns = {'MalNo' : 'UrunSinifSayisi'}),on = 'KategoriSinifTamami', 
                               how = 'inner')

# %%
malOzellik2['UrunSinifSayisi'] = malOzellik2['UrunSinifSayisi'] - 1

# %%
satis_stok = satisTarihIndex.merge(stokTarihIndex, how = 'outer', on = ['MalNo', 'TarihIndex'])

# %%
satis_stok_imha = satis_stok.merge(imhaTarihIndex, how = 'outer', on = ['MalNo', 'TarihIndex'])

# %%
total_data = satis_stok_imha.merge(malOzellik2, how = 'inner', on = 'MalNo')

# %%
#total_data.to_csv('raw_data-2016-satis-olan.csv', sep = ';', index = False)

# %%
total_data['Gun'] = total_data['TarihIndex'].dt.day
total_data['Ay'] = total_data['TarihIndex'].dt.month
total_data['Ceyrek'] = total_data['TarihIndex'].dt.quarter
total_data['Yil'] = total_data['TarihIndex'].dt.year
total_data['DayOfYear'] = total_data['TarihIndex'].dt.dayofyear
total_data['DayOfWeek'] = total_data['TarihIndex'].dt.dayofweek
total_data['MonthStart'] = total_data['TarihIndex'].dt.is_month_start
total_data['Weekend'] = np.where(total_data['DayOfWeek'] > 5,1,0)
total_data['MonthStart'] = np.where(total_data['MonthStart'] == True,1,0)

# %%
#total_data.to_csv('train_data_4.csv', sep = ';', index = False)

# %%
#total_data[total_data['MalNo'] == 12284590].sort_values('TarihIndex')
total_data_fillna = total_data.fillna(0)
#total_data_fillna['SatisNetTutar'] / total_data_fillna['SatisMiktar']

# %%
#total_data_fillna.to_csv('train_data_5.csv', sep = ';', index = False)

# %%
total_data_fillna['YilBasinaUzaklik'] = (pd.to_datetime(total_data_fillna['Yil'].map(str) + '-12-31') - total_data_fillna['TarihIndex'])/ np.timedelta64(1, 'D')

# %%
GunlukSatisOrtalamasi = total_data_fillna[['MalNo', 'SatisMiktar', 'DayOfWeek']].groupby(
    ['MalNo','DayOfWeek']).mean().rename(
    columns = {'SatisMiktar': 'GunlukSatisOrtalamasi'})

# %%
GunlukSatisMedian = total_data_fillna[['MalNo', 'SatisMiktar', 'DayOfWeek']].groupby(
    ['MalNo','DayOfWeek']).median().rename(
    columns = {'SatisMiktar': 'GunlukSatisMedian'})

# %%
satis['DayOfWeek'] = satis['TarihIndex'].dt.dayofweek
satis['Quarter'] = satis['TarihIndex'].dt.quarter

# %%
GunlukSatisOrt2016 = satis[satis['TarihIndex'] >= '2016-01-01'][['MalNo', 'DayOfWeek', 'SatisMiktar']].groupby(
    ['MalNo','DayOfWeek']).mean().rename(columns = {'SatisMiktar' : 'GunlukSatisOrt2016'})

# %%
GunlukSatisMed2016 = satis[satis['TarihIndex'] >= '2016-01-01'][['MalNo', 'DayOfWeek', 'SatisMiktar']].groupby(
    ['MalNo','DayOfWeek']).median().rename(columns = {'SatisMiktar' : 'GunlukSatisMed2016'})

# %% [markdown]
# GunlukSatisOrt2016q = satis[satis['TarihIndex'] >= '2016-01-01'][['MalNo', 'DayOfWeek',
#                                                                   'Quarter', 'SatisMiktar']].groupby(
#     ['MalNo','DayOfWeek', 'Quarter']).mean().rename(columns = {'SatisMiktar' : 'GunlukSatisOrt2016q'})

# %% [markdown]
# GunlukSatisMed2016q = satis[satis['TarihIndex'] >= '2016-01-01'][['MalNo', 'DayOfWeek',
#                                                                   'Quarter', 'SatisMiktar']].groupby(
#     ['MalNo','DayOfWeek', 'Quarter']).mean().rename(columns = {'SatisMiktar' : 'GunlukSatisOrt2016q'})

# %%
total_data_fillna = total_data_fillna.merge(GunlukSatisOrtalamasi, how = 'inner', on = ['MalNo', 'DayOfWeek'])

# %%
total_data_fillna = total_data_fillna.merge(GunlukSatisMedian, how = 'inner', on = ['MalNo', 'DayOfWeek'])

# %%
total_data_fillna = total_data_fillna.merge(GunlukSatisOrt2016, how = 'inner', on = ['MalNo', 'DayOfWeek'])

# %%
total_data_fillna = total_data_fillna.merge(GunlukSatisMed2016, how = 'inner', on = ['MalNo', 'DayOfWeek'])

# %%
total_data_fillna.head()
# Out:
#       MalNo  SatisMiktar  SatisNetTutar TarihIndex  StokMiktar  ImhaMiktar  \
# 0  12284590          2.0          35.59 2014-01-01         1.0         0.0
# 1  12284590          2.0          62.55 2014-12-24         2.0         0.0
# 2  12284590          3.0         101.43 2015-12-09        14.0         0.0
# 3  12284590          1.0          33.81 2016-12-21         4.0         0.0
# 4  12284590          1.0          38.05 2016-12-28         3.0         0.0
#
#    KategoriAnaGrupNo  KategoriGrupNo  KategoriSinifNo  KategoriAltSinifNo  \
# 0                300              10               11                  10
# 1                300              10               11                  10
# 2                300              10               11                  10
# 3                300              10               11                  10
# 4                300              10               11                  10
#
#           ...           Yil DayOfYear  DayOfWeek  MonthStart  Weekend  \
# 0         ...          2014         1          2           1        0
# 1         ...          2014       358          2           0        0
# 2         ...          2015       343          2           0        0
# 3         ...          2016       356          2           0        0
# 4         ...          2016       363          2           0        0
#
#    YilBasinaUzaklik  GunlukSatisOrtalamasi  GunlukSatisMedian  \
# 0             364.0                   0.25                0.0
# 1               7.0                   0.25                0.0
# 2              22.0                   0.25                0.0
# 3              10.0                   0.25                0.0
# 4               3.0                   0.25                0.0
#
#    GunlukSatisOrt2016  GunlukSatisMed2016
# 0                 1.0                 1.0
# 1                 1.0                 1.0
# 2                 1.0                 1.0
# 3                 1.0                 1.0
# 4                 1.0                 1.0
#
# [5 rows x 27 columns]

# %%
total_data_fillna.corr()
# Out:
#                           MalNo  SatisMiktar  SatisNetTutar  StokMiktar  \
# MalNo                  1.000000    -0.054722      -0.050967    0.019472
# SatisMiktar           -0.054722     1.000000       0.782576    0.116461
# SatisNetTutar         -0.050967     0.782576       1.000000   -0.011462
# StokMiktar             0.019472     0.116461      -0.011462    1.000000
# ImhaMiktar             0.002571     0.318204       0.234406    0.177305
# KategoriAnaGrupNo      0.044785    -0.138769      -0.148602   -0.017822
# KategoriGrupNo        -0.129516    -0.087822      -0.054516   -0.109608
# KategoriSinifNo        0.012412     0.142379       0.137211    0.012889
# KategoriAltSinifNo    -0.276335     0.035451      -0.014262   -0.017304
# UrunSayisi             0.078187    -0.077349      -0.072290   -0.000675
# UrunSinifSayisi       -0.041489     0.013970       0.019842    0.042164
# Gun                    0.001122     0.000366       0.002369   -0.013994
# Ay                     0.030790     0.002152      -0.017273    0.006735
# Ceyrek                 0.030532     0.000504      -0.019221    0.007572
# Yil                    0.059914     0.020843       0.021668    0.022234
# DayOfYear              0.030955     0.002193      -0.017045    0.005598
# DayOfWeek             -0.000747     0.043662       0.045822    0.000149
# MonthStart            -0.000533     0.001088       0.002235    0.003350
# Weekend                0.002993     0.046935       0.045266   -0.005193
# YilBasinaUzaklik      -0.030691    -0.002120       0.017107   -0.005490
# GunlukSatisOrtalamasi -0.074168     0.737811       0.642388    0.049079
# GunlukSatisMedian     -0.086240     0.671134       0.622224   -0.000952
# GunlukSatisOrt2016    -0.049374     0.693686       0.585337    0.077489
# GunlukSatisMed2016    -0.051418     0.673943       0.555295    0.076154
#
#                        ImhaMiktar  KategoriAnaGrupNo  KategoriGrupNo  \
# MalNo                    0.002571           0.044785       -0.129516
# SatisMiktar              0.318204          -0.138769       -0.087822
# SatisNetTutar            0.234406          -0.148602       -0.054516
# StokMiktar               0.177305          -0.017822       -0.109608
# ImhaMiktar               1.000000          -0.076511       -0.109709
# KategoriAnaGrupNo       -0.076511           1.000000        0.469241
# KategoriGrupNo          -0.109709           0.469241        1.000000
# KategoriSinifNo          0.000892           0.126273       -0.048134
# KategoriAltSinifNo      -0.009664           0.018747        0.130523
# UrunSayisi              -0.016222          -0.165679       -0.366196
# UrunSinifSayisi          0.153404          -0.201265       -0.279492
# Gun                      0.002350           0.010374        0.004115
# Ay                       0.017577           0.000094       -0.021244
# Ceyrek                   0.017010           0.000619       -0.021432
# Yil                      0.016803          -0.033365       -0.022565
# DayOfYear                0.017739           0.000961       -0.020887
# DayOfWeek               -0.001430           0.001757        0.000194
# MonthStart               0.002070          -0.006356       -0.003069
# Weekend                  0.001250          -0.002809       -0.001150
# YilBasinaUzaklik        -0.017715          -0.001057        0.020764
# GunlukSatisOrtalamasi    0.281420          -0.188083       -0.119030
# GunlukSatisMedian        0.277925          -0.181569       -0.084415
# GunlukSatisOrt2016       0.278536          -0.178886       -0.136507
# GunlukSatisMed2016       0.282413          -0.172546       -0.131274
#
#                        KategoriSinifNo  KategoriAltSinifNo  UrunSayisi  \
# MalNo                         0.012412           -0.276335    0.078187
# SatisMiktar                   0.142379            0.035451   -0.077349
# SatisNetTutar                 0.137211           -0.014262   -0.072290
# StokMiktar                    0.012889           -0.017304   -0.000675
# ImhaMiktar                    0.000892           -0.009664   -0.016222
# KategoriAnaGrupNo             0.126273            0.018747   -0.165679
# KategoriGrupNo               -0.048134            0.130523   -0.366196
# KategoriSinifNo               1.000000            0.385416   -0.334530
# KategoriAltSinifNo            0.385416            1.000000   -0.401033
# UrunSayisi                   -0.334530           -0.401033    1.000000
# UrunSinifSayisi              -0.202664           -0.169852    0.370759
# Gun                           0.000066           -0.000741    0.001055
# Ay                           -0.002279           -0.015688    0.009264
# Ceyrek                       -0.001545           -0.016081    0.008439
# Yil                          -0.045144           -0.051082    0.066985
# DayOfYear                    -0.002372           -0.015791    0.009500
# DayOfWeek                    -0.008646           -0.006994    0.012265
# MonthStart                   -0.000607           -0.000333    0.000849
# Weekend                      -0.007475           -0.005026    0.007728
# YilBasinaUzaklik              0.002220            0.015593   -0.009211
# GunlukSatisOrtalamasi         0.192976            0.048049   -0.104836
# GunlukSatisMedian             0.183126            0.061972   -0.097689
# GunlukSatisOrt2016            0.171069            0.042335   -0.105303
# GunlukSatisMed2016            0.159842            0.054972   -0.104176
#
#                               ...               Yil  DayOfYear  DayOfWeek  \
# MalNo                         ...          0.059914   0.030955  -0.000747
# SatisMiktar                   ...          0.020843   0.002193   0.043662
# SatisNetTutar                 ...          0.021668  -0.017045   0.045822
# StokMiktar                    ...          0.022234   0.005598   0.000149
# ImhaMiktar                    ...          0.016803   0.017739  -0.001430
# KategoriAnaGrupNo             ...         -0.033365   0.000961   0.001757
# KategoriGrupNo                ...         -0.022565  -0.020887   0.000194
# KategoriSinifNo               ...         -0.045144  -0.002372  -0.008646
# KategoriAltSinifNo            ...         -0.051082  -0.015791  -0.006994
# UrunSayisi                    ...          0.066985   0.009500   0.012265
# UrunSinifSayisi               ...          0.013539   0.010627   0.003811
# Gun                           ...         -0.002911   0.094895   0.003981
# Ay                            ...         -0.018888   0.996590  -0.007472
# Ceyrek                        ...         -0.017730   0.968977  -0.002046
# Yil                           ...          1.000000  -0.015666   0.002075
# DayOfYear                     ...         -0.015666   1.000000  -0.007121
# DayOfWeek                     ...          0.002075  -0.007121   1.000000
# MonthStart                    ...          0.002883  -0.028098  -0.005400
# Weekend                       ...         -0.001208  -0.004757   0.612220
# YilBasinaUzaklik              ...          0.019662  -0.999990   0.007128
# GunlukSatisOrtalamasi         ...         -0.005094  -0.003140   0.059177
# GunlukSatisMedian             ...          0.004216  -0.004071   0.054371
# GunlukSatisOrt2016            ...         -0.003633  -0.002503   0.057014
# GunlukSatisMed2016            ...         -0.002265  -0.003622   0.056272
#
#                        MonthStart   Weekend  YilBasinaUzaklik  \
# MalNo                   -0.000533  0.002993         -0.030691
# SatisMiktar              0.001088  0.046935         -0.002120
# SatisNetTutar            0.002235  0.045266          0.017107
# StokMiktar               0.003350 -0.005193         -0.005490
# ImhaMiktar               0.002070  0.001250         -0.017715
# KategoriAnaGrupNo       -0.006356 -0.002809         -0.001057
# KategoriGrupNo          -0.003069 -0.001150          0.020764
# KategoriSinifNo         -0.000607 -0.007475          0.002220
# KategoriAltSinifNo      -0.000333 -0.005026          0.015593
# UrunSayisi               0.000849  0.007728         -0.009211
# UrunSinifSayisi          0.000619  0.002009         -0.010630
# Gun                     -0.306037 -0.000676         -0.094897
# Ay                      -0.002918 -0.004680         -0.996597
# Ceyrek                  -0.003059 -0.004236         -0.968982
# Yil                      0.002883 -0.001208          0.019662
# DayOfYear               -0.028098 -0.004757         -0.999990
# DayOfWeek               -0.005400  0.612220          0.007128
# MonthStart               1.000000  0.000452          0.028100
# Weekend                  0.000452  1.000000          0.004750
# YilBasinaUzaklik         0.028100  0.004750          1.000000
# GunlukSatisOrtalamasi    0.002892  0.063615          0.003082
# GunlukSatisMedian        0.002556  0.060142          0.004048
# GunlukSatisOrt2016       0.002707  0.057349          0.002464
# GunlukSatisMed2016       0.002668  0.057924          0.003588
#
#                        GunlukSatisOrtalamasi  GunlukSatisMedian  \
# MalNo                              -0.074168          -0.086240
# SatisMiktar                         0.737811           0.671134
# SatisNetTutar                       0.642388           0.622224
# StokMiktar                          0.049079          -0.000952
# ImhaMiktar                          0.281420           0.277925
# KategoriAnaGrupNo                  -0.188083          -0.181569
# KategoriGrupNo                     -0.119030          -0.084415
# KategoriSinifNo                     0.192976           0.183126
# KategoriAltSinifNo                  0.048049           0.061972
# UrunSayisi                         -0.104836          -0.097689
# UrunSinifSayisi                     0.018935           0.055103
# Gun                                -0.003801          -0.004057
# Ay                                 -0.002765          -0.003694
# Ceyrek                             -0.002132          -0.003294
# Yil                                -0.005094           0.004216
# DayOfYear                          -0.003140          -0.004071
# DayOfWeek                           0.059177           0.054371
# MonthStart                          0.002892           0.002556
# Weekend                             0.063615           0.060142
# YilBasinaUzaklik                    0.003082           0.004048
# GunlukSatisOrtalamasi               1.000000           0.909629
# GunlukSatisMedian                   0.909629           1.000000
# GunlukSatisOrt2016                  0.940195           0.770642
# GunlukSatisMed2016                  0.913436           0.758192
#
#                        GunlukSatisOrt2016  GunlukSatisMed2016
# MalNo                           -0.049374           -0.051418
# SatisMiktar                      0.693686            0.673943
# SatisNetTutar                    0.585337            0.555295
# StokMiktar                       0.077489            0.076154
# ImhaMiktar                       0.278536            0.282413
# KategoriAnaGrupNo               -0.178886           -0.172546
# KategoriGrupNo                  -0.136507           -0.131274
# KategoriSinifNo                  0.171069            0.159842
# KategoriAltSinifNo               0.042335            0.054972
# UrunSayisi                      -0.105303           -0.104176
# UrunSinifSayisi                 -0.023367           -0.036935
# Gun                             -0.003299           -0.003140
# Ay                              -0.002237           -0.003398
# Ceyrek                          -0.001447           -0.002679
# Yil                             -0.003633           -0.002265
# DayOfYear                       -0.002503           -0.003622
# DayOfWeek                        0.057014            0.056272
# MonthStart                       0.002707            0.002668
# Weekend                          0.057349            0.057924
# YilBasinaUzaklik                 0.002464            0.003588
# GunlukSatisOrtalamasi            0.940195            0.913436
# GunlukSatisMedian                0.770642            0.758192
# GunlukSatisOrt2016               1.000000            0.982784
# GunlukSatisMed2016               0.982784            1.000000
#
# [24 rows x 24 columns]

# %%
total_data_fillna.to_csv('train_data_7.csv', sep = ';', index = False)
